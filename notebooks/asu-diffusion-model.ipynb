# %% [markdown]
# The ASU Diffusion Model

# %%
from diffusion import run_diffusion_model

# %%
run_diffusion_model()
# Out:
# array([0.00000000e+00, 1.38745041e-06, 2.78436175e-06, 4.18127309e-06,
#        5.60666490e-06, 7.03205670e-06, 8.50524217e-06, 9.97842764e-06,
#        1.15192115e-05, 1.30599954e-05, 1.46888750e-05, 1.63177545e-05,
#        1.80561251e-05, 1.97944958e-05, 2.16648619e-05, 2.35352281e-05,
#        2.55614216e-05, 2.75876151e-05, 2.97950215e-05, 3.20024279e-05,
#        3.44182222e-05, 3.68340165e-05, 3.94874101e-05, 4.21408038e-05,
#        4.50633034e-05, 4.79858030e-05, 5.12114828e-05, 5.44371626e-05,
#        5.80029514e-05, 6.15687402e-05, 6.55147246e-05, 6.94607090e-05,
#        7.38304541e-05, 7.82001991e-05, 8.30410874e-05, 8.78819756e-05,
#        9.32455664e-05, 9.86091573e-05, 1.04551568e-04, 1.10493978e-04,
#        1.17076285e-04, 1.23658593e-04, 1.30947262e-04, 1.38235932e-04,
#        1.46303269e-04, 1.54370606e-04, 1.63295235e-04, 1.72219863e-04,
#        1.82087232e-04, 1.91954601e-04, 2.02857519e-04, 2.13760436e-04,
# ...
